# %%
import numpy as np
import pandas as pd 
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os

# %% [markdown]
# Define constants

# %%
FAST_RUN = False
IMAGE_WIDTH=128
IMAGE_HEIGHT=128
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %% [markdown]
# Prepare data

# %% [markdown]
# Download data and save it

# %%
url = 'https://drive.google.com/file/d/1gjbSZV5NjjIVOqSP-yTCqXcGPX9PnYn5/view?usp=sharing'

# %%
# !gdown --id 1gjbSZV5NjjIVOqSP-yTCqXcGPX9PnYn5
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1gjbSZV5NjjIVOqSP-yTCqXcGPX9PnYn5
# To: /content/MM17-WeiboRumorSet.zip
# 1.35GB [00:15, 86.4MB/s]

# %% [markdown]
# Unzip and save into folder train_extracted

# %%
import zipfile
with zipfile.ZipFile("MM17-WeiboRumorSet.zip","r") as zip_ref:
    zip_ref.extractall("./train_extracted")

# %% [markdown]
# Exract labels from image names and save image names with corresponding labels in dataframe

# %%
filenames1 = os.listdir("./train_extracted/MM17-WeiboRumorSet/rumor_images")
filenames01 = []
categories1 = []
for filename in filenames1:
    category = 1 # rumor
    categories1.append(1)
    s = "rumor_images/"+str(filename)
    filenames01.append(s)

df1 = pd.DataFrame({
    'filename': filenames01,
    'category': categories1
})

# %%
df1.head()
# Out:
#                                             filename  category
# 0            rumor_images/a062f201jw1e37vmjleroj.jpg         1
# 1  rumor_images/005HTrunjw1ev1dxkkfwbj30en0jn416.jpg         1
# 2  rumor_images/006blktQgw1ev0er4n5yuj30c80i8q59.jpg         1
# 3  rumor_images/0065Xfyojw1estmvpj3hcj30hs0hsdig.jpg         1
# 4  rumor_images/883057f5jw1eg9lbepl8nj20hm2iidmh.jpg         1

# %%
len(df1) # number of rumor images
# Out:
# 7954

# %%
filenames2 = os.listdir("./train_extracted/MM17-WeiboRumorSet/nonrumor_images")
filenames02 = []
categories2 = []
for filename in filenames2:
    category2 = 0 # rumor
    categories2.append(0)
    s = "nonrumor_images/"+str(filename)
    filenames02.append(s)

df2 = pd.DataFrame({
    'filename': filenames02,
    'category': categories2
})

# %%
df2.head()
# Out:
#                                             filename  category
# 0  nonrumor_images/75b52ed2jw1ez51qwegv3j20ov0gi7...         0
# 1  nonrumor_images/75b52ed2jw1ez0d79g4q3j20hs0s0a...         0
# 2  nonrumor_images/624c2f04gw1ezc3ggtn40j21081c64...         0
# 3  nonrumor_images/470bf257jw1ezboyzhtwdj20hr0ggd...         0
# 4  nonrumor_images/62914aabjw1ez9fqbk038j20wr18gw...         0

# %%
len(df2) # number of non rumor images
# Out:
# 5318

# %%
df = df1.append(df2, ignore_index=True).reset_index(drop = True)

# %%
df.head()
# Out:
#                                             filename  category
# 0            rumor_images/a062f201jw1e37vmjleroj.jpg         1
# 1  rumor_images/005HTrunjw1ev1dxkkfwbj30en0jn416.jpg         1
# 2  rumor_images/006blktQgw1ev0er4n5yuj30c80i8q59.jpg         1
# 3  rumor_images/0065Xfyojw1estmvpj3hcj30hs0hsdig.jpg         1
# 4  rumor_images/883057f5jw1eg9lbepl8nj20hm2iidmh.jpg         1

# %%
len(df) # combined
# Out:
# 13272

# %%
df.describe()
# Out:
#            category
# count  13272.000000
# mean       0.599307
# std        0.490057
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
df.tail()
# Out:
#                                                 filename  category
# 13267  nonrumor_images/655dd5f3gw1ez1kzzdk92j20c80963...         0
# 13268  nonrumor_images/593bbc68gw1eywqjm6zeoj20ak07sj...         0
# 13269  nonrumor_images/62914aabjw1ezgmmwxn3mj20bz0ds7...         0
# 13270  nonrumor_images/75b52ed2jw1ez1ajvv0gej20c80brt...         0
# 13271  nonrumor_images/6a918093gw1euuyl86srfj209p064m...         0

# %% [markdown]
# Total count

# %%
label_counts = df.groupby('category').size()
print(label_counts)
# Out:
# category
# 0    5318
# 1    7954
# dtype: int64

# %%
df['category'].value_counts().plot.bar()

# %% [markdown]
# Sample image

# %% [markdown]
# Shuffle df

# %%
# shuffle the DataFrame rows 
df = df.sample(frac = 1).reset_index(drop=True)

# %%
df.head()
# Out:
#                                             filename  category
# 0  rumor_images/b7c32acbjw1etpccv1wi1j20f00qoacu.jpg         1
# 1  nonrumor_images/620beb06gw1eyl3ydgbmkj20c8092t...         0
# 2  rumor_images/725ba55bgw1ev34ok5hujj20hs0b4q3v.jpg         1
# 3  rumor_images/0065Offujw1es83p0sx2xj30hr0qojuq.jpg         1
# 4  rumor_images/0065y37ojw1etffto714ej30e80e8dg5.jpg         1

# %%
df.tail()
# Out:
#                                                 filename  category
# 13267  rumor_images/96b5d279jw1et1hkfp00fj20f10qodgo.jpg         1
# 13268  nonrumor_images/75b52ed2jw1exmh7b44afj21400qon...         0
# 13269            rumor_images/7c748631jw1dwnydthzq0j.jpg         1
# 13270  rumor_images/005tcrrhjw1ev19iowmvjj30f00qowgn.jpg         1
# 13271  nonrumor_images/4ee36f05gw1exy0mmiu6jj20eg09ed...         0

# %% [markdown]
# Make a combined list with rumor and non rumor image paths last part

# %%
filenames = []
categories = []
for i in range(0, len(df)):
  filenames.append(str(df['filename'][i]))
  categories.append((df['category'][i]))
print(len(filenames))
print(len(categories))
# Out:
# 13272
# 13272

# %%
print(filenames[0])
print(categories[0])
print(filenames[-1])
print(categories[-1])
# Out:
# rumor_images/b7c32acbjw1etpccv1wi1j20f00qoacu.jpg
# 1
# nonrumor_images/4ee36f05gw1exy0mmiu6jj20eg09edgd.jpg
# 0

# %%
sample = random.choice(filenames)
print(sample)
image = load_img("./train_extracted/MM17-WeiboRumorSet/"+sample)
plt.imshow(image)
# Out:
# rumor_images/89df55e9jw1dz9i2x5l4wj.jpg

# %%
sample = random.choice(filenames)
print(sample)
image = load_img("./train_extracted/MM17-WeiboRumorSet/"+sample)
plt.imshow(image)
# Out:
# rumor_images/8d40fa0bjw1eu7yljd88cj20nq0hstbe.jpg

# %%
sample = random.choice(filenames)
print(sample)
image = load_img("./train_extracted/MM17-WeiboRumorSet/"+sample)
plt.imshow(image)
# Out:
# rumor_images/69a8c584jw1ev5hac5iz8j20ee0kq0tz.jpg

# %%
sample = random.choice(filenames)
print(sample)
image = load_img("./train_extracted/MM17-WeiboRumorSet/"+sample)
plt.imshow(image)
# Out:
# nonrumor_images/63207a53jw1ezma58csl2j20go0cijsp.jpg

# %% [markdown]
# Build Model
#
#
# Input Layer: It represent input image data. It will reshape image into single diminsion array. Example your image is 64x64 = 4096, it will convert to (4096,1) array.
#
# Conv Layer: This layer will extract features from image.
#
# Pooling Layer: This layerreduce the spatial volume of input image after convolution.
#
# Fully Connected Layer: It connect the network from a layer to another layer
#
# Output Layer: It is the predicted values layer.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax')) # 2 because we have cat and dog classes

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 126, 126, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 126, 126, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 61, 61, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               12845568
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 12,942,786
# Trainable params: 12,941,314
# Non-trainable params: 1,472
# _________________________________________________________________

# %% [markdown]
# Callbacks

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# Early Stop
#
# To prevent over fitting we will stop the learning after 10 epochs and val_loss value not decreased

# %%
earlystop = EarlyStopping(patience=10)

# %% [markdown]
# Learning Rate Reduction
#
# We will reduce the learning rate when then accuracy not increase for 2 steps

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
callbacks = [earlystop, learning_rate_reduction]

# %% [markdown]
# Prepare data
#
# Because we will use image genaretor with class_mode="categorical". We need to convert column category into string. Then imagenerator will convert it one-hot encoding which is good for our classification.
#
# So we will convert 1 to rumor and 0 to nonrumor

# %%
df["category"] = df["category"].replace({0: 'nonrumor', 1: 'rumor'})

# %%
df.head()
# Out:
#                                             filename  category
# 0  rumor_images/b7c32acbjw1etpccv1wi1j20f00qoacu.jpg     rumor
# 1  nonrumor_images/620beb06gw1eyl3ydgbmkj20c8092t...  nonrumor
# 2  rumor_images/725ba55bgw1ev34ok5hujj20hs0b4q3v.jpg     rumor
# 3  rumor_images/0065Offujw1es83p0sx2xj30hr0qojuq.jpg     rumor
# 4  rumor_images/0065y37ojw1etffto714ej30e80e8dg5.jpg     rumor

# %% [markdown]
# Divide into 50% train and 50% test, Note that we have shuffled earlier

# %%
mid = int(len(df)/2)
df_train = df[:mid]
df_test = df[mid:]
print(len(df_train))
print(len(df_test))
# Out:
# 6636
# 6636

# %%
train_df, validate_df = train_test_split(df_train, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['category'].value_counts().plot.bar()

# %%
validate_df['category'].value_counts().plot.bar()

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size=15

# %% [markdown]
# Traning Generator

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    "./train_extracted/MM17-WeiboRumorSet/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 5297 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/dataframe_iterator.py:282: UserWarning: Found 11 invalid image filename(s) in x_col="filename". These filename(s) will be ignored.
#   .format(n_invalid, x_col)

# %% [markdown]
# Validation Generator

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    "./train_extracted/MM17-WeiboRumorSet/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 1327 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/dataframe_iterator.py:282: UserWarning: Found 1 invalid image filename(s) in x_col="filename". These filename(s) will be ignored.
#   .format(n_invalid, x_col)

# %% [markdown]
# See how our generator work

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    "./train_extracted/MM17-WeiboRumorSet/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical'
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# Seems great

# %% [markdown]
# Fit Model

# %%
FAST_RUN = False

# %%
epochs=3 if FAST_RUN else 50
history = model.fit_generator(
    train_generator, 
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# WARNING:tensorflow:From <ipython-input-45-63cb34b6e89a>:8: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 353/353 [==============================] - 64s 181ms/step - loss: 1.0210 - accuracy: 0.5477 - val_loss: 0.6769 - val_accuracy: 0.5924
# Epoch 2/50
# 353/353 [==============================] - 63s 179ms/step - loss: 0.7543 - accuracy: 0.5695 - val_loss: 0.7561 - val_accuracy: 0.5273
# Epoch 3/50
# 353/353 [==============================] - 64s 181ms/step - loss: 0.6867 - accuracy: 0.6028 - val_loss: 0.7439 - val_accuracy: 0.6076
# Epoch 4/50
# 353/353 [==============================] - 64s 180ms/step - loss: 0.6842 - accuracy: 0.5996 - val_loss: 0.6400 - val_accuracy: 0.6341
# Epoch 5/50
# 353/353 [==============================] - 63s 178ms/step - loss: 0.6685 - accuracy: 0.6032 - val_loss: 0.6420 - val_accuracy: 0.6250
# Epoch 6/50
# 353/353 [==============================] - 63s 178ms/step - loss: 0.6648 - accuracy: 0.6077 - val_loss: 0.6320 - val_accuracy: 0.6553
# Epoch 7/50
# 353/353 [==============================] - 63s 178ms/step - loss: 0.6611 - accuracy: 0.6251 - val_loss: 0.8522 - val_accuracy: 0.5583
# Epoch 8/50
# 353/353 [==============================] - ETA: 0s - loss: 0.6549 - accuracy: 0.6176
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 353/353 [==============================] - 63s 179ms/step - loss: 0.6549 - accuracy: 0.6176 - val_loss: 0.6460 - val_accuracy: 0.6114
# Epoch 9/50
# 353/353 [==============================] - 63s 179ms/step - loss: 0.6304 - accuracy: 0.6407 - val_loss: 0.6065 - val_accuracy: 0.6735
# Epoch 10/50
# 353/353 [==============================] - 63s 178ms/step - loss: 0.6233 - accuracy: 0.6435 - val_loss: 0.5960 - val_accuracy: 0.6818
# Epoch 11/50
# 353/353 [==============================] - 63s 178ms/step - loss: 0.6177 - accuracy: 0.6499 - val_loss: 0.6305 - val_accuracy: 0.6417
# Epoch 12/50
# 353/353 [==============================] - ETA: 0s - loss: 0.6174 - accuracy: 0.6494
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 353/353 [==============================] - 63s 178ms/step - loss: 0.6174 - accuracy: 0.6494 - val_loss: 0.6097 - val_accuracy: 0.6591
# Epoch 13/50
# 353/353 [==============================] - 63s 178ms/step - loss: 0.6034 - accuracy: 0.6604 - val_loss: 0.5842 - val_accuracy: 0.6977
# Epoch 14/50
# 353/353 [==============================] - 63s 180ms/step - loss: 0.5956 - accuracy: 0.6702 - val_loss: 0.5982 - val_accuracy: 0.6667
# Epoch 15/50
# 353/353 [==============================] - ETA: 0s - loss: 0.5959 - accuracy: 0.6683
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 353/353 [==============================] - 63s 179ms/step - loss: 0.5959 - accuracy: 0.6683 - val_loss: 0.6123 - val_accuracy: 0.6667
# Epoch 16/50
# 353/353 [==============================] - 63s 179ms/step - loss: 0.5884 - accuracy: 0.6740 - val_loss: 0.5749 - val_accuracy: 0.6970
# Epoch 17/50
# 353/353 [==============================] - ETA: 0s - loss: 0.5898 - accuracy: 0.6808
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 353/353 [==============================] - 63s 179ms/step - loss: 0.5898 - accuracy: 0.6808 - val_loss: 0.5850 - val_accuracy: 0.6856
# Epoch 18/50
# 353/353 [==============================] - 63s 180ms/step - loss: 0.5826 - accuracy: 0.6799 - val_loss: 0.5765 - val_accuracy: 0.6879
# Epoch 19/50
# 353/353 [==============================] - ETA: 0s - loss: 0.5796 - accuracy: 0.6842
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 353/353 [==============================] - 63s 179ms/step - loss: 0.5796 - accuracy: 0.6842 - val_loss: 0.5788 - val_accuracy: 0.6962
# Epoch 20/50
# 353/353 [==============================] - 63s 178ms/step - loss: 0.5716 - accuracy: 0.6980 - val_loss: 0.5930 - val_accuracy: 0.6856
# Epoch 21/50
# 353/353 [==============================] - 63s 179ms/step - loss: 0.5719 - accuracy: 0.6965 - val_loss: 0.5811 - val_accuracy: 0.6992
# Epoch 22/50
# 353/353 [==============================] - 63s 179ms/step - loss: 0.5752 - accuracy: 0.6827 - val_loss: 0.5865 - val_accuracy: 0.6955
# Epoch 23/50
# 353/353 [==============================] - ETA: 0s - loss: 0.5738 - accuracy: 0.6958
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 353/353 [==============================] - 63s 179ms/step - loss: 0.5738 - accuracy: 0.6958 - val_loss: 0.5969 - val_accuracy: 0.6848
# Epoch 24/50
# 353/353 [==============================] - 63s 180ms/step - loss: 0.5730 - accuracy: 0.6956 - val_loss: 0.5871 - val_accuracy: 0.6947
# Epoch 25/50
# 353/353 [==============================] - ETA: 0s - loss: 0.5743 - accuracy: 0.6903
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1e-05.
# 353/353 [==============================] - 63s 179ms/step - loss: 0.5743 - accuracy: 0.6903 - val_loss: 0.5960 - val_accuracy: 0.6841
# Epoch 26/50
# 353/353 [==============================] - 63s 180ms/step - loss: 0.5728 - accuracy: 0.6948 - val_loss: 0.5869 - val_accuracy: 0.6985

# %% [markdown]
# Save Model

# %%
model.save_weights("model.h5")

# %%
model.save_weights("Rumor_Nonrumor_50epochs_model.h5")

# %%
# saving the dataframe 
df.to_csv('df_5331.csv')

# %%
# saving the dataframe 
df_train.to_csv('df_train_5331.csv')
# saving the dataframe 
df_test.to_csv('df_test_5331.csv')

# %%
from google.colab import files
files.download('Rumor_Nonrumor_50epochs_model.h5')

# %%
files.download('df_5331.csv') 
files.download('df_train_5331.csv') 
files.download('df_test_5331.csv')

# %%
model.load_weights("model.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %% [markdown]
# Visualize Training

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(history.history['loss'], color='b', label="Training loss")
ax1.plot(history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, epochs, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(history.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(np.arange(1, epochs, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Prepare Testing Data

# %%
df_test.head()
# Out:
#                                                filename  category
# 6636  rumor_images/7224a200jw1ekfssiawjwj20ci0fk75r.jpg     rumor
# 6637  rumor_images/470c8f41jw1eeeqwwexshj20f00qomz0.jpg     rumor
# 6638  rumor_images/b1eba1a4jw1entv37mlt0j20f00qoq88.jpg     rumor
# 6639  rumor_images/9fb6970bgw1exi126c2r4j20p018gn1s.jpg     rumor
# 6640  nonrumor_images/6693ce84gw1eynssnesnsj20c80c6q...  nonrumor

# %%
df_test = df_test.reset_index(drop = True)

# %%
test_filenames = []
test_categories = []
for i in range(0,len(df_test)):
  test_filenames.append(df_test['filename'][i])
  test_categories.append(df_test['category'][i])
print(len(test_filenames))
# Out:
# 6636

# %%
test_df = df_test
nb_samples = test_df.shape[0]

# %% [markdown]
# Create Testing Generator

# %%
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    test_df, 
    "./train_extracted/MM17-WeiboRumorSet/", 
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False,
    validate_filenames=False
)
# Out:
# Found 6636 non-validated image filenames.

# %% [markdown]
# Predict

# %%
predict = model.predict(test_generator, steps=np.ceil(nb_samples/batch_size))

# %%
print(predict)
# Out:
# [[0.50795573 0.49204427]
#  [0.19103861 0.80896145]
#  [0.6191509  0.38084915]
#  ...
#  [0.03802766 0.9619724 ]
#  [0.14276843 0.8572316 ]
#  [0.6413469  0.3586531 ]]

# %% [markdown]
# For categoral classication the prediction will come with probability of each category. So we will pick the category that have the highest probability with numpy average max

# %%
test_df['category_predicted'] = np.argmax(predict, axis=-1)

# %% [markdown]
# We will convert the predict category back into our generator classes by using train_generator.class_indices. It is the classes that image generator map while converting data into computer vision

# %%
label_map = dict((v,k) for k,v in train_generator.class_indices.items())
test_df['category_predicted'] = test_df['category_predicted'].replace(label_map)

# %% [markdown]
# From our prepare data part. We map data with {1: 'dog', 0: 'cat'}. Now we will map the result back to dog is 1 and cat is 0

# %%
test_df['category_predicted'] = test_df['category_predicted'].replace({ 'rumor': 1, 'nonrumor': 0 })
test_df['category'] = test_df['category'].replace({ 'rumor': 1, 'nonrumor': 0 })

# %% [markdown]
# Virtaulize Result

# %%
test_df['category_predicted'].value_counts().plot.bar()

# %%
test_df['category'].value_counts().plot.bar()

# %%
y_pred = test_df['category_predicted']
y_true = test_df['category']

# %%
from sklearn.metrics import accuracy_score # normal accuracy
from sklearn.metrics import balanced_accuracy_score # used in case of imbalanced data sets, average of recall, from 0 to 1
from sklearn.metrics import confusion_matrix # division of performance on the multilabels
from sklearn.metrics import cohen_kappa_score # compares model against random prediction, from -1 to 1
from sklearn.metrics import classification_report # for multilabel classification, gives precision, recall, f score, support, more
target_names = ['class 0', 'class 1']

def print_metrics(y_true, y_pred):
    print("Accuracy:", accuracy_score(y_true, y_pred))
    print("Balanced Accuracy:" , balanced_accuracy_score(y_true, y_pred))
    print("Confusion Matrix:\n", confusion_matrix(y_true, y_pred))
    print("Cohen Kappa Score:", cohen_kappa_score(y_true, y_pred))
    print("Classification Report:\n", classification_report(y_true, y_pred, target_names=target_names))
    
print('CNN Only')
print_metrics(y_true, y_pred)
# Out:
# CNN Only
# Accuracy: 0.688667872212176
# Balanced Accuracy: 0.6890872551116362
# Confusion Matrix:
#  [[1854  828]
#  [1238 2716]]
# Cohen Kappa Score: 0.36909864608608545
# Cohen Kappa Score: 0.36909864608608545
# Classification Report:
#                precision    recall  f1-score   support
#
#      class 0       0.60      0.69      0.64      2682
#      class 1       0.77      0.69      0.72      3954
#
#     accuracy                           0.69      6636
#    macro avg       0.68      0.69      0.68      6636
# weighted avg       0.70      0.69      0.69      6636

# %% [markdown]
# See predicted result with images

# %%
sample_test = test_df.head(18)
sample_test.head()
plt.figure(figsize=(12, 24))
for index, row in sample_test.iterrows():
    filename = row['filename']
    category = row['category']
    category_predicted = row['category_predicted']
    img = load_img("./train_extracted/MM17-WeiboRumorSet/"+filename, target_size=IMAGE_SIZE)
    plt.subplot(6, 3, index+1)
    plt.imshow(img)
    plt.xlabel(filename[int(3*len(filename)/4):] + '(' + "{}".format(category) + ')' + '(' + "{}".format(category_predicted) + ')' )
plt.tight_layout()
plt.show()

# %%
# saving the dataframe of our results
test_df.to_csv('test_df_5331.csv') 
files.download('test_df_5331.csv')
